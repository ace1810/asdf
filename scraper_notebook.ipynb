# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Function to check if a string is in English
def is_english(text):
    return bool(re.match(r'^[a-zA-Z0-9\s,.\'-]*$', text))

# Function to scrape data from one page
def scrape_page(page_url):
    response = requests.get(page_url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page_url}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = soup.find_all('div', class_='content--3JNQz')
    
    data = []
    for listing in listings:
        title_element = listing.find('h2')
        title = title_element.get_text(strip=True) if title_element else 'N/A'
        
        if is_english(title):
            price_element = listing.find('div', class_='price--3SnqI')
            price = price_element.get_text(strip=True) if price_element else 'N/A'
            
            data.append({
                'Title': title,
                'Price': price
            })
    return data

# Function to scrape multiple pages
def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page in range(1, num_pages + 1):
        print(f"Scraping page {page}")
        page_url = f"{base_url}&page={page}"
        all_data.extend(scrape_page(page_url))
    return all_data

# Main function
def main():
    base_url = "https://bikroy.com/en/ads/dhaka/apartments-for-sale?sort=date&order=desc&buy_now=0&urgent=0"
    num_pages = 5  # Change this to the number of pages you want to scrape
    data = scrape_multiple_pages(base_url, num_pages)
    
    # Save data to Excel
    df = pd.DataFrame(data)
    df.to_excel('bikroy_apartments.xlsx', index=False)
    print("Data saved to bikroy_apartments.xlsx")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Data saved to bikroy_apartments.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Function to check if a string is in English
def is_english(text):
    return bool(re.match(r'^[a-zA-Z0-9\s,.\'-]*$', text))

# Function to scrape the address from a listing page
def get_address(listing_url):
    response = requests.get(listing_url)
    if response.status_code != 200:
        print(f"Failed to fetch listing page: {listing_url}")
        return "N/A"
    
    soup = BeautifulSoup(response.text, 'html.parser')
    address_element = soup.find('div', class_='word-break--2nyVq value--1lKHt')
    return address_element.get_text(strip=True) if address_element else "N/A"

# Function to scrape data from one page
def scrape_page(page_url):
    response = requests.get(page_url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page_url}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = soup.find_all('a', class_='card-link--3ssYv gtm-ad-item')
    
    data = []
    for listing in listings:
        title_element = listing.find('h2')
        title = title_element.get_text(strip=True) if title_element else 'N/A'
        
        if is_english(title):
            price_element = listing.find('div', class_='price--3SnqI')
            price = price_element.get_text(strip=True) if price_element else 'N/A'
            
            listing_url = f"https://bikroy.com{listing['href']}"
            address = get_address(listing_url)
            
            data.append({
                'Title': title,
                'Price': price,
                'Address': address
            })
    return data

# Function to scrape multiple pages
def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page in range(1, num_pages + 1):
        print(f"Scraping page {page}")
        page_url = f"{base_url}&page={page}"
        all_data.extend(scrape_page(page_url))
    return all_data

# Main function
def main():
    base_url = "https://bikroy.com/en/ads/dhaka/apartments-for-sale?sort=date&order=desc&buy_now=0&urgent=0"
    num_pages = 5  # Adjust the number of pages to scrape
    data = scrape_multiple_pages(base_url, num_pages)
    
    # Save data to Excel
    df = pd.DataFrame(data)
    df.to_excel('bikroy_apartments_with_addresses.xlsx', index=False)
    print("Data saved to bikroy_apartments_with_addresses.xlsx")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Data saved to bikroy_apartments_with_addresses.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from tqdm import tqdm  # Progress bar library

# Function to check if a string is in English
def is_english(text):
    return bool(re.match(r'^[a-zA-Z0-9\s,.\'-]*$', text))

# Function to scrape the address from a listing page
def get_address(listing_url):
    response = requests.get(listing_url)
    if response.status_code != 200:
        print(f"Failed to fetch listing page: {listing_url}")
        return "N/A"
    
    soup = BeautifulSoup(response.text, 'html.parser')
    address_element = soup.find('div', class_='word-break--2nyVq value--1lKHt')
    return address_element.get_text(strip=True) if address_element else "N/A"

# Function to scrape data from one page
def scrape_page(page_url):
    response = requests.get(page_url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page_url}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = soup.find_all('a', class_='card-link--3ssYv gtm-ad-item')
    
    data = []
    for listing in tqdm(listings, desc="Processing listings", unit="listing"):
        title_element = listing.find('h2')
        title = title_element.get_text(strip=True) if title_element else 'N/A'
        
        if is_english(title):
            price_element = listing.find('div', class_='price--3SnqI')
            price = price_element.get_text(strip=True) if price_element else 'N/A'
            
            listing_url = f"https://bikroy.com{listing['href']}"
            address = get_address(listing_url)
            
            data.append({
                'Title': title,
                'Price': price,
                'Address': address
            })
    return data

# Function to scrape multiple pages
def scrape_multiple_pages(base_url, num_pages):
    all_data = []
    for page in tqdm(range(1, num_pages + 1), desc="Scraping pages", unit="page"):
        page_url = f"{base_url}&page={page}"
        page_data = scrape_page(page_url)
        all_data.extend(page_data)
    return all_data

# Main function
def main():
    base_url = "https://bikroy.com/en/ads/dhaka/apartments-for-sale?sort=date&order=desc&buy_now=0&urgent=0"
    num_pages = 100  # Adjust the number of pages to scrape
    data = scrape_multiple_pages(base_url, num_pages)
    
    # Save data to Excel
    df = pd.DataFrame(data)
    df.to_excel('bikroy_apartments_with_addresses.xlsx', index=False)
    print("Data saved to bikroy_apartments_with_addresses.xlsx")

if __name__ == "__main__":
    main()
# Out:
# Scraping pages:   0%|                                                                        | 0/100 [00:00<?, ?page/s]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:00<00:07,  3.08listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:01<00:07,  2.61listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:03<00:07,  2.30listing/s]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:04<00:09,  1.61listing/s]
# Processing listings:  40%|██████████████████████▍                                 | 10/25 [00:05<00:10,  1.46listing/s]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:07<00:14,  1.04s/listing]
# Processing listings:  48%|██████████████████████████▉                             | 12/25 [00:09<00:14,  1.13s/listing]
# Processing listings:  68%|██████████████████████████████████████                  | 17/25 [00:11<00:05,  1.56listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:12<00:00,  2.01listing/s]
# Scraping pages:   1%|▋                                                               | 1/100 [00:14<23:13, 14.07s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:00<00:01, 11.59listing/s]
# Processing listings:  48%|██████████████████████████▉                             | 12/25 [00:01<00:02,  6.02listing/s]
# Processing listings:  52%|█████████████████████████████                           | 13/25 [00:03<00:03,  3.19listing/s]
# Processing listings:  76%|██████████████████████████████████████████▌             | 19/25 [00:04<00:01,  4.09listing/s]
# Processing listings:  80%|████████████████████████████████████████████▊           | 20/25 [00:05<00:01,  2.99listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:06<00:00,  4.10listing/s]
# Scraping pages:   2%|█▎                                                              | 2/100 [00:21<16:54, 10.35s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   8%|████▌                                                    | 2/25 [00:01<00:11,  1.97listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:03<00:28,  1.32s/listing]
# Processing listings:  28%|███████████████▉                                         | 7/25 [00:04<00:09,  1.92listing/s]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:05<00:07,  2.03listing/s]
# Processing listings:  80%|████████████████████████████████████████████▊           | 20/25 [00:05<00:00,  5.32listing/s]
# Processing listings:  84%|███████████████████████████████████████████████         | 21/25 [00:06<00:00,  4.25listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:07<00:00,  3.14listing/s]
# Scraping pages:   3%|█▉                                                              | 3/100 [00:30<15:49,  9.79s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   4%|██▎                                                      | 1/25 [00:00<00:14,  1.71listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:01<00:12,  1.80listing/s]
# Processing listings:  16%|█████████                                                | 4/25 [00:02<00:15,  1.39listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:03<00:17,  1.14listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:04<00:16,  1.15listing/s]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:05<00:04,  2.81listing/s]
# Processing listings:  60%|█████████████████████████████████▌                      | 15/25 [00:06<00:02,  3.43listing/s]
# Processing listings:  64%|███████████████████████████████████▊                    | 16/25 [00:07<00:03,  2.66listing/s]
# Processing listings:  72%|████████████████████████████████████████▎               | 18/25 [00:08<00:03,  1.94listing/s]
# Processing listings:  76%|██████████████████████████████████████████▌             | 19/25 [00:09<00:03,  1.70listing/s]
# Processing listings:  88%|█████████████████████████████████████████████████▎      | 22/25 [00:10<00:01,  2.00listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:11<00:00,  2.13listing/s]
# Scraping pages:   4%|██▌                                                             | 4/100 [00:44<17:44, 11.09s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   8%|████▌                                                    | 2/25 [00:00<00:09,  2.50listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:02<00:20,  1.09listing/s]
# Processing listings:  28%|███████████████▉                                         | 7/25 [00:03<00:07,  2.25listing/s]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:04<00:07,  2.00listing/s]
# Processing listings:  76%|██████████████████████████████████████████▌             | 19/25 [00:05<00:01,  5.14listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:07<00:00,  3.46listing/s]
# Scraping pages:   5%|███▏                                                            | 5/100 [00:52<16:03, 10.14s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:  16%|█████████                                                | 4/25 [00:01<00:08,  2.47listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:02<00:09,  2.05listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:03<00:11,  1.60listing/s]
# Processing listings:  28%|███████████████▉                                         | 7/25 [00:04<00:12,  1.49listing/s]
# Processing listings:  48%|██████████████████████████▉                             | 12/25 [00:04<00:04,  3.03listing/s]
# Processing listings:  52%|█████████████████████████████                           | 13/25 [00:05<00:04,  2.43listing/s]
# Processing listings:  64%|███████████████████████████████████▊                    | 16/25 [00:06<00:03,  2.78listing/s]
# Processing listings:  76%|██████████████████████████████████████████▌             | 19/25 [00:07<00:02,  2.86listing/s]
# Processing listings:  84%|███████████████████████████████████████████████         | 21/25 [00:09<00:01,  2.26listing/s]
# Processing listings:  88%|█████████████████████████████████████████████████▎      | 22/25 [00:10<00:01,  1.90listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:11<00:00,  2.22listing/s]
# Scraping pages:   6%|███▊                                                            | 6/100 [01:06<18:05, 11.54s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   4%|██▎                                                      | 1/25 [00:01<00:25,  1.05s/listing]
# Processing listings:   8%|████▌                                                    | 2/25 [00:01<00:22,  1.03listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:02<00:20,  1.05listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:03<00:13,  1.53listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:04<00:07,  2.21listing/s]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:05<00:10,  1.56listing/s]
# Processing listings:  92%|███████████████████████████████████████████████████▌    | 23/25 [00:06<00:00,  5.59listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:07<00:00,  3.20listing/s]
# Scraping pages:   7%|████▍                                                           | 7/100 [01:15<16:42, 10.78s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   4%|██▎                                                      | 1/25 [00:00<00:19,  1.22listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:02<00:14,  1.47listing/s]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:02<00:02,  5.09listing/s]
# Processing listings:  48%|██████████████████████████▉                             | 12/25 [00:03<00:04,  3.20listing/s]
# Processing listings:  52%|█████████████████████████████                           | 13/25 [00:04<00:05,  2.38listing/s]
# Processing listings:  56%|███████████████████████████████▎                        | 14/25 [00:06<00:06,  1.81listing/s]
# Processing listings:  60%|█████████████████████████████████▌                      | 15/25 [00:06<00:05,  1.71listing/s]
# Processing listings:  64%|███████████████████████████████████▊                    | 16/25 [00:07<00:05,  1.52listing/s]
# Processing listings:  68%|██████████████████████████████████████                  | 17/25 [00:08<00:05,  1.39listing/s]
# Processing listings:  72%|████████████████████████████████████████▎               | 18/25 [00:09<00:05,  1.19listing/s]
# Processing listings:  84%|███████████████████████████████████████████████         | 21/25 [00:10<00:02,  1.85listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:11<00:00,  2.09listing/s]
# Scraping pages:   8%|█████                                                           | 8/100 [01:29<17:38, 11.51s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   4%|██▎                                                      | 1/25 [00:00<00:18,  1.28listing/s]
# Processing listings:  16%|█████████                                                | 4/25 [00:01<00:09,  2.18listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:02<00:11,  1.69listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:04<00:14,  1.34listing/s]
# Processing listings:  28%|███████████████▉                                         | 7/25 [00:05<00:15,  1.19listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:05<00:13,  1.22listing/s]
# Processing listings:  64%|███████████████████████████████████▊                    | 16/25 [00:06<00:02,  3.84listing/s]
# Processing listings:  68%|██████████████████████████████████████                  | 17/25 [00:07<00:02,  3.22listing/s]
# Processing listings:  80%|████████████████████████████████████████████▊           | 20/25 [00:08<00:01,  2.84listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:09<00:00,  2.69listing/s]
# Scraping pages:   9%|█████▊                                                          | 9/100 [01:40<17:16, 11.39s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   4%|██▎                                                      | 1/25 [00:01<00:28,  1.19s/listing]
# Processing listings:   8%|████▌                                                    | 2/25 [00:02<00:27,  1.18s/listing]
# Processing listings:  16%|█████████                                                | 4/25 [00:03<00:14,  1.46listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:04<00:20,  1.03s/listing]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:05<00:19,  1.01s/listing]
# Processing listings:  36%|████████████████████▌                                    | 9/25 [00:06<00:09,  1.69listing/s]
# Processing listings:  40%|██████████████████████▍                                 | 10/25 [00:07<00:09,  1.65listing/s]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:08<00:09,  1.49listing/s]
# Processing listings:  92%|███████████████████████████████████████████████████▌    | 23/25 [00:07<00:00,  3.72listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:09<00:00,  2.71listing/s]
# Scraping pages:  32%|████████████████████▏                                          | 32/100 [07:00<15:05, 13.31s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:00<00:02,  6.91listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:01<00:06,  3.04listing/s]
# Processing listings:  28%|███████████████▉                                         | 7/25 [00:03<00:11,  1.63listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:04<00:11,  1.44listing/s]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:05<00:07,  1.82listing/s]
# Processing listings:  56%|███████████████████████████████▎                        | 14/25 [00:06<00:05,  1.85listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:08<00:00,  3.07listing/s]
# Scraping pages:  33%|████████████████████▊                                          | 33/100 [07:10<13:45, 12.33s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:00<00:02,  8.04listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:01<00:03,  4.32listing/s]
# Processing listings:  56%|███████████████████████████████▎                        | 14/25 [00:02<00:01,  5.76listing/s]
# Processing listings:  64%|███████████████████████████████████▊                    | 16/25 [00:04<00:03,  2.92listing/s]
# Processing listings:  80%|████████████████████████████████████████████▊           | 20/25 [00:06<00:02,  2.40listing/s]
# Processing listings:  84%|███████████████████████████████████████████████         | 21/25 [00:07<00:01,  2.18listing/s]
# Processing listings:  88%|█████████████████████████████████████████████████▎      | 22/25 [00:08<00:01,  1.56listing/s]
# Processing listings: 100%|████████████████████████████████████████████████████████| 25/25 [00:11<00:00,  2.18listing/s]
# Scraping pages:  34%|█████████████████████▍                                         | 34/100 [07:23<13:44, 12.49s/page]
# Processing listings:   0%|                                                                 | 0/25 [00:00<?, ?listing/s]
# Processing listings:   8%|████▌                                                    | 2/25 [00:02<00:24,  1.07s/listing]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:03<00:27,  1.24s/listing]
# Processing listings:  16%|█████████                                                | 4/25 [00:04<00:22,  1.08s/listing]
# Processing listings:  20%|███████████▍                                             | 5/25 [00:05<00:21,  1.09s/listing]
# Processing listings:  44%|████████████████████████▋                               | 11/25 [00:06<00:05,  2.66listing/s]
# Processing listings:  48%|██████████████████████████▉                             | 12/25 [00:07<00:06,  2.12listing/s]
# Processing listings:  52%|█████████████████████████████                           | 13/25 [00:08<00:07,  1.56listing/s]
# ...
# Processing listings:   4%|██▎                                                      | 1/25 [00:00<00:18,  1.29listing/s]
# Processing listings:  12%|██████▊                                                  | 3/25 [00:01<00:12,  1.76listing/s]
# Processing listings:  24%|█████████████▋                                           | 6/25 [00:02<00:07,  2.62listing/s]
# Processing listings:  32%|██████████████████▏                                      | 8/25 [00:03<00:06,  2.47listing/s]
